# %%
import numpy as np
import matplotlib.pyplot as plt
import jsonpickle
import jsonpickle.ext.numpy as jsonpickle_numpy
import qctrlvisualizer as qv
jsonpickle_numpy.register_handlers()
import time
import qutip as qt
# %matplotlib inline

waveform_path = "../dr7run6_te62fnal001_qoc_qctrl/waveforms/"

# %% [markdown]
# # Hamiltonian Setting

# %%
# System parameters.
chi = -2 * np.pi * 70 * 1e3  # rad.Hz
K = -2 * np.pi * 0  # rad.Hz
delta = 0  # rad.Hz
delta_c = 0
alpha = -2 * np.pi * 246 * 1e6  # rad.Hz

transmon_dimension = 4  # Transmon dimensions.
cavity_dimension = 18  # Cavity dimensions.

qt_a = qt.tensor(qt.qeye(transmon_dimension), qt.destroy(cavity_dimension))
qt_b = qt.tensor(qt.destroy(transmon_dimension), qt.qeye(cavity_dimension))

sigz = - 2 * qt_b.dag() * qt_b + qt.tensor(qt.qeye(transmon_dimension), qt.qeye(cavity_dimension))
sigx = qt_b.dag() + qt_b
sigy = 1j * (qt_b.dag() - qt_b)

transmon_0_proj = qt.tensor(qt.basis(transmon_dimension, 0) * qt.basis(transmon_dimension, 0).dag() ,qt.qeye(cavity_dimension))
transmon_1_proj = qt.tensor(qt.basis(transmon_dimension, 1) * qt.basis(transmon_dimension, 1).dag() ,qt.qeye(cavity_dimension))
transmon_2_proj = qt.tensor(qt.basis(transmon_dimension, 2) * qt.basis(transmon_dimension, 2).dag() ,qt.qeye(cavity_dimension))
# transmon_3_proj = qt.tensor(qt.basis(transmon_dimension, 3) * qt.basis(transmon_dimension, 3).dag() ,qt.qeye(cavity_dimension))

cavity_0_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 0) * qt.basis(cavity_dimension, 0).dag())
cavity_1_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 1) * qt.basis(cavity_dimension, 1).dag())
cavity_2_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 2) * qt.basis(cavity_dimension, 2).dag())
cavity_3_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 3) * qt.basis(cavity_dimension, 3).dag())
cavity_4_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 4) * qt.basis(cavity_dimension, 4).dag())
cavity_5_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 5) * qt.basis(cavity_dimension, 5).dag())
cavity_6_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 6) * qt.basis(cavity_dimension, 6).dag())
cavity_7_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 7) * qt.basis(cavity_dimension, 7).dag())
cavity_8_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 8) * qt.basis(cavity_dimension, 8).dag())
cavity_9_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 9) * qt.basis(cavity_dimension, 9).dag())
cavity_10_proj = qt.tensor(qt.qeye(transmon_dimension), qt.basis(cavity_dimension, 10) * qt.basis(cavity_dimension, 10).dag())


psi0 = qt.tensor(qt.basis(transmon_dimension, 0), qt.basis(cavity_dimension, 0))

qt_H_static = delta_c * qt_a.dag() * qt_a + K / 2 * qt_a.dag() * qt_a.dag() * qt_a * qt_a + alpha / 2 * qt_b.dag() * qt_b.dag() * qt_b * qt_b + chi * qt_a.dag() * qt_a * qt_b.dag() * qt_b
qt_H_static = qt_H_static / 1e9 # changing the unit to GHz

# %% [markdown]
# # Simulation

# %%
# Read and write helper functions, type independent.
def save_variable(file_name, var):
    """
    Save a single variable to a file using jsonpickle.
    """
    with open(file_name, "w+") as file:
        file.write(jsonpickle.encode(var))


def load_variable(file_name):
    """
    Load a variable from a file encoded with jsonpickle.
    """
    with open(file_name, "r+") as file:
        return jsonpickle.decode(file.read())

two_pi = 2 * np.pi

def get_time():
    return " "+time.strftime(r'%Y-%m-%d %H-%M-%S',time.localtime())


def generate_drive_from_array(complex_array, dt=1):
    out=[]
    for d in complex_array:
        for i in range(dt):
            out.append(d)
    
    return np.array(out)

def plot_pulse(qubit_control, cavity_control, figsize=(10,8), control_name="QOC pulse"):
    fig, ax  = plt.subplots(2,1, figsize=figsize)
    ax[0].plot(np.real(qubit_control) / (two_pi) * 1e3, label="transmon I")
    ax[0].plot(np.imag(qubit_control) / (two_pi) * 1e3, label="transmon Q")
    ax[1].plot(np.real(cavity_control) / (two_pi) * 1e3, label="cavity I")
    ax[1].plot(np.imag(cavity_control) / (two_pi) * 1e3, label="cavity Q")
    ax[0].set_xlabel("Time (ns)")
    ax[1].set_xlabel("Time (ns)")
    ax[0].set_ylabel("$\\Omega/2\pi$ (MHz)")
    ax[1].set_ylabel("$\\epsilon/2\pi$ (MHz)")
    ax[0].legend(loc='upper right')
    ax[1].legend(loc='upper right')
    ax[0].axhline(y=0, color='black')
    ax[0].grid()
    ax[1].axhline(y=0, color='black')
    ax[1].grid()
    ax[0].set_title(control_name);
    fig.tight_layout()

def system_dynamics(free_hamiltonian, qubit_control, cavity_control):
    tlist = np.linspace(0, len(qubit_control)-1, len(qubit_control))

    qt_transmon_I_drive_func = qt.coefficient(np.real(qubit_control), tlist=tlist)
    qt_transmon_Q_drive_func = qt.coefficient(np.imag(qubit_control), tlist=tlist)
    qt_cavity_I_drive_func = qt.coefficient(np.real(cavity_control), tlist=tlist)
    qt_cavity_Q_drive_func = qt.coefficient(np.imag(cavity_control), tlist=tlist)

    qt_H_transmon_I = [(qt_b + qt_b.dag()) / 2, qt_transmon_I_drive_func]
    qt_H_transmon_Q = [-1j * (qt_b - qt_b.dag()) / 2, qt_transmon_Q_drive_func]
    qt_H_cavity_I = [(qt_a + qt_a.dag()) / 2, qt_cavity_I_drive_func]
    qt_H_cavity_Q = [-1j * (qt_a - qt_a.dag()) / 2, qt_cavity_Q_drive_func]

    qt_H_total = [free_hamiltonian, qt_H_transmon_I, qt_H_transmon_Q, qt_H_cavity_I, qt_H_cavity_Q]
    options = qt.Options(rtol=1e-12, atol=1e-12, nsteps = 1000000, store_states = True)
    e_ops = [qt_a.dag() * qt_a, qt_b.dag() * qt_b, sigx, sigy, sigz, transmon_0_proj, transmon_1_proj, transmon_2_proj, cavity_0_proj, cavity_1_proj, cavity_2_proj, cavity_3_proj, cavity_4_proj, cavity_5_proj, cavity_6_proj, cavity_7_proj,cavity_8_proj,cavity_9_proj, cavity_10_proj]

    psi0 = qt.tensor(qt.basis(transmon_dimension, 0), qt.basis(cavity_dimension, 0))
    res = qt.mesolve(qt_H_total, psi0, tlist, e_ops=e_ops, options=options)

    return tlist, res

def extract_results(res):
    cavity_population = res.expect[0]
    transmon_population = res.expect[1]
    sigx_exp = res.expect[2]
    sigy_exp = res.expect[3]
    sigz_exp = res.expect[4]
    transmon_0_exp = res.expect[5]
    transmon_1_exp = res.expect[6]
    transmon_2_exp = res.expect[7]
    cavity_0_exp = res.expect[8]
    cavity_1_exp = res.expect[9]
    cavity_2_exp = res.expect[10]
    cavity_3_exp = res.expect[11]
    cavity_4_exp = res.expect[12]
    cavity_5_exp = res.expect[13]
    cavity_6_exp = res.expect[14]
    cavity_7_exp = res.expect[15]
    cavity_8_exp = res.expect[16]
    cavity_9_exp = res.expect[17]
    cavity_10_exp = res.expect[18]

    results ={
        "transmon_n": transmon_population,
        "cavity_n": cavity_population,
        "transmon x": sigx_exp,
        "transmon y": sigy_exp,
        "transmon z": sigz_exp,
        "transmon g": transmon_0_exp,
        "transmon e": transmon_1_exp,
        "transmon f": transmon_2_exp,
        "cavity 0": cavity_0_exp,
        "cavity 1": cavity_1_exp,
        "cavity 2": cavity_2_exp,
        "cavity 3": cavity_3_exp,
        "cavity 4": cavity_4_exp,
        "cavity 5": cavity_5_exp,
        "cavity 6": cavity_6_exp,
        "cavity 7": cavity_7_exp,
        "cavity 8": cavity_8_exp,
        "cavity 9": cavity_9_exp,
        "cavity 10": cavity_10_exp
    }

    return results

# %% [markdown]
# ## 500ns Robust Pi from San

# %%
fname = "robust_pi_500ns.npy"
data = np.load(waveform_path+fname)
data_dt = 2

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")

cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
# /Users/taeyoon/anaconda3/envs/opal-env4/lib/python3.10/site-packages/qutip/solver/options.py:16: FutureWarning: Dedicated options class are no longer needed, options should be passed as dict to solvers.
#   warnings.warn(
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-a68f2d7ccd1f4fb18c763131e3160893"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-a68f2d7ccd1f4fb18c763131e3160893"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-a68f2d7ccd1f4fb18c763131e3160893"
#         >Play</button>
#     </div>

# %%
len(qt_transmon_drive)
# Out:
# 500

# %%
fig, ax = plt.subplots()
ax.plot(np.real(qt_transmon_drive))
ax.plot(np.imag(qt_transmon_drive))

# %%
np.save("san_robust_pi_500ns.npy", qt_transmon_drive)

# %% [markdown]
# ## 60ns Robust Pi from Qctrl

# %%
fname = "robust_dephasing_controls_20240924-163050"
robust_dephasing_controls = load_variable(waveform_path+fname)
qctrl_pulse = robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values']

# %%
fname = "robust_dephasing_controls_20240924-163050"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")

cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-f40fb9c6e2a2458ea40247403e173a38"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-f40fb9c6e2a2458ea40247403e173a38"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-f40fb9c6e2a2458ea40247403e173a38"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_pi_60ns.npy", qt_transmon_drive)

# %% [markdown]
# # 100ns Robust Pi from Qctrl

# %%
fname = "robust_dephasing_controls_20240924-163050_2"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-8ab182443da74e92960cc373c019ace9"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-8ab182443da74e92960cc373c019ace9"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-8ab182443da74e92960cc373c019ace9"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_pi_100ns.npy", qt_transmon_drive)

# %% [markdown]
# ## 100 ns Robust X90 from Qctrl

# %%
fname = "x90_100ns20240924-163050"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-0e6e9e25077045eebe9d0c6e1051703a"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-0e6e9e25077045eebe9d0c6e1051703a"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-0e6e9e25077045eebe9d0c6e1051703a"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_xpi2_100ns.npy", qt_transmon_drive)

# %% [markdown]
# ## 60 ns Robust X90 from Qctrl

# %%
fname = "x90_60ns20240924-163050"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-2a1592ec73cc4b9692a0bc50f8597c6e"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-2a1592ec73cc4b9692a0bc50f8597c6e"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-2a1592ec73cc4b9692a0bc50f8597c6e"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_xpi2_60ns.npy", qt_transmon_drive)

# %%
fname = "y90_60ns20240924-163050"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["Q-CTRL"]["I"]['values'] + 1j * robust_dephasing_controls["Q-CTRL"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-223ee9d434cb4b60afe3a1f39b1c6eab"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-223ee9d434cb4b60afe3a1f39b1c6eab"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-223ee9d434cb4b60afe3a1f39b1c6eab"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_ypi2_60ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi_40ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-bfc6fe550f4d44618178631b993b3364"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-bfc6fe550f4d44618178631b993b3364"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-bfc6fe550f4d44618178631b993b3364"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_xpi_40ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi2_40ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-e6705849c5e44d3385b403a74c323df8"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-e6705849c5e44d3385b403a74c323df8"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-e6705849c5e44d3385b403a74c323df8"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_xpi2_40ns.npy", qt_transmon_drive)

# %%
fname = "qoc_y_pi2_40ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-201c0212f9d84156b31d58404cd89935"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-201c0212f9d84156b31d58404cd89935"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-201c0212f9d84156b31d58404cd89935"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_robust_ypi2_40ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi2n_40ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-dc68e9b750d64f09b1669f6c5e8b34ad"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-dc68e9b750d64f09b1669f6c5e8b34ad"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-dc68e9b750d64f09b1669f6c5e8b34ad"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_xpi2n_40ns.npy", qt_transmon_drive)

# %%
fname = "qoc_y_pi2n_40ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-fea477cc1768428aa381dca5705e1375"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-fea477cc1768428aa381dca5705e1375"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-fea477cc1768428aa381dca5705e1375"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_ypi2n_40ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi_20ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-cce35da05283458ca4788cb8cba8e89d"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-cce35da05283458ca4788cb8cba8e89d"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-cce35da05283458ca4788cb8cba8e89d"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_xpi_20ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi2_20ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-76a07966e4584f17bfc0831a0107708f"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-76a07966e4584f17bfc0831a0107708f"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-76a07966e4584f17bfc0831a0107708f"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_xpi2_20ns.npy", qt_transmon_drive)

# %%
fname = "qoc_x_pi2n_20ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-d77f83c8ce194be791da742943e09293"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-d77f83c8ce194be791da742943e09293"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-d77f83c8ce194be791da742943e09293"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_xpi2n_20ns.npy", qt_transmon_drive)

# %%
fname = "qoc_y_pi2_20ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-7c86caa54e654641992aeb72afd96bfe"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-7c86caa54e654641992aeb72afd96bfe"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-7c86caa54e654641992aeb72afd96bfe"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_ypi2_20ns.npy", qt_transmon_drive)

# %%
fname = "qoc_y_pi2n_20ns"
robust_dephasing_controls = load_variable(waveform_path+fname)
data = (robust_dephasing_controls["output"]["I"]['values'] + 1j * robust_dephasing_controls["output"]["Q"]['values'] )/ 1e9

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
# /Users/taeyoon/anaconda3/envs/opal-env4/lib/python3.10/site-packages/qutip/solver/options.py:16: FutureWarning: Dedicated options class are no longer needed, options should be passed as dict to solvers.
#   warnings.warn(
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-2aff8df4aa5b4cd483267eeaad6ddb79"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-2aff8df4aa5b4cd483267eeaad6ddb79"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-2aff8df4aa5b4cd483267eeaad6ddb79"
#         >Play</button>
#     </div>

# %%
np.save("qctrl_qoc_ypi2n_20ns.npy", qt_transmon_drive)

# %%
fname = "yunwei_pi_40ns.npy"
path = waveform_path + fname
data = np.load(path)

def delete_duplicate(input_array):
    output_array = []
    for i in input_array:
        if i not in output_array:
            output_array.append(i)
    return np.array(output_array)

t, i , q = data.transpose()
new_i = delete_duplicate(i)
new_q = delete_duplicate(q)

data = (new_i + 1j * new_q)

data_dt = 1

qt_transmon_drive = generate_drive_from_array(data, data_dt)
qt_cavity_drive = np.zeros_like(qt_transmon_drive)

plot_pulse(qt_transmon_drive, qt_cavity_drive, control_name=fname, figsize=(8,4))

qt_tlist, qt_results = system_dynamics(qt_H_static, qt_transmon_drive, qt_cavity_drive)
results_dict = extract_results(qt_results)

qubit_g_population = results_dict["transmon g"]
qubit_e_population = results_dict["transmon e"]
qubit_f_population = results_dict["transmon f"]
qubit_x = results_dict["transmon x"]
qubit_y = results_dict["transmon y"]
qubit_z = results_dict["transmon z"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, qubit_g_population, label="g")
ax[0].plot(qt_tlist, qubit_e_population, label="e")
ax[0].plot(qt_tlist, qubit_f_population, label="f")
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].legend(loc='upper right')
ax[0].grid()
ax[0].set_title("Transmon state populations")
ax[1].plot(qt_tlist, qubit_x, label="x")
ax[1].plot(qt_tlist, qubit_y, label="y")
ax[1].plot(qt_tlist, qubit_z, label="z")
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Expectation value")
ax[1].grid()
ax[1].legend(loc='upper right')
ax[1].set_title("Transmon bloch sphere vector components")
ax[1].axhline(y=0, color='black')

cavity_0 = results_dict["cavity 0"]
cavity_1 = results_dict["cavity 1"]
cavity_2 = results_dict["cavity 2"]
cavity_3 = results_dict["cavity 3"]
cavity_4 = results_dict["cavity 4"]
cavity_5 = results_dict["cavity 5"]
cavity_6 = results_dict["cavity 6"]
cavity_7 = results_dict["cavity 7"]
cavity_8 = results_dict["cavity 8"]
cavity_9 = results_dict["cavity 9"]
cavity_10 = results_dict["cavity 10"]

fig, ax = plt.subplots(1,2, figsize=(18,5))
ax[0].plot(qt_tlist, cavity_0, label="0")
ax[0].plot(qt_tlist, cavity_1, label="1")
ax[0].plot(qt_tlist, cavity_2, label="2")
ax[0].plot(qt_tlist, cavity_3, label="3")
ax[0].legend(loc='upper right')
ax[0].set_xlabel("Time (ns)")
ax[0].set_ylabel("Population")
ax[0].grid()
ax[0].set_title("Cavity state populations")
cavity_photon_prob = [cavity_0, cavity_1, cavity_2, cavity_3, cavity_4, cavity_5, cavity_6, cavity_7, cavity_8, cavity_9, cavity_10]
cavity_photon_list = np.linspace(0, len(cavity_photon_prob)-1, len(cavity_photon_prob))
levs = np.linspace(0, 1, 100)
plot1 = ax[1].contourf(qt_tlist, cavity_photon_list, cavity_photon_prob, levs, cmap='viridis')
ax[1].set_xlabel("Time (ns)")
ax[1].set_ylabel("Cavity photon number")
ax[1].set_title("Cavity photon number dynamics")
ax[1].grid(linestyle='--')
ax[1].set_yticks(np.linspace(0,10,11))
cl_bar = plt.colorbar(plot1)
cl_bar.set_ticks(np.arange(0,1+0.1,0.1))

bloch_vector_array = np.array([qubit_x, qubit_y, qubit_z]).transpose()

qv.display_bloch_sphere_from_bloch_vectors(bloch_vector_array)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-fdec734aec1a4cea83e19bba05c31db0"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-fdec734aec1a4cea83e19bba05c31db0"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-fdec734aec1a4cea83e19bba05c31db0"
#         >Play</button>
#     </div>

# %%
fig, ax = plt.subplots()
ax.plot(new_i)
ax.plot(new_q)
